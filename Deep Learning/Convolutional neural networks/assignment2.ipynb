# %% [markdown]
# Name: Shan Kuan, Student ID: 604888

# %% [markdown]
# $$\pagebreak$$

# %% [markdown]
# # Exercise on Convolutional Neural Networks

# %% [markdown]
# <p>In this exercise you will extend and improve the accuracy of the Convolution Neural Network discussed in the demonstration by doing the following things: </p>
# <ul>
# <li>Creating a deep Convolutional Neural Network.</li>
# <li>Tweaking the hyper-parameters such as the number of channels in each layer, activation functions, mini batch size, etc;</li>
# </ul>
# <p>The architecture of the network that we will create is similar to the figure below (This figure will not be displayed when exported to .pdf):</p>

# %% [markdown]
# <img src="https://i.imgur.com/AjQYgPv.png" alt="Demo Architecture" title="Figure 1" width="500" />

# %% [markdown]
# <p>We will begin by first importing the necessary python libraries:</p>

# %%
import os
import six.moves.cPickle as pickle
import gzip
import numpy
import theano
import theano.tensor as T
import matplotlib.pyplot as plt
import random as rd
from theano.tensor.signal import pool
from theano.tensor.nnet import conv2d
from exercise_helper import load_data, pooling, convLayer
from exercise_helper import fullyConnectedLayer
from exercise_helper import negative_log_lik, errors
from exercise_helper import generate_plot
# %matplotlib inline
# Setting the random number generator
rng = numpy.random.RandomState(23455)
print('***** Import complete *****')
# Out:
# ***** Import complete *****

# %% [markdown]
# <p><b>Note: If the import of 'exercise_helper' fails, ensure that 'exercise_helper.py' is in the same folder as this notebook.</b>

# %% [markdown]
# <p>Now we can create the Theano Computation Graph. We shall partition the data into mini-batches and then create a computation graph for training, validation and testing. The overall logic is very similar to the demonstration. Refer to the demonstration for more details.</p>

# %%
def train_test_conv_net(learning_rate, num_epochs,
                        num_filters, mini_batch_size, activation):
    # Function to create the convolutional neural network, train and
    # evaluate it. This function must be called to run the network.
    
    # Inputs:
    # learning_rate - Learning rate for Stochastic Gradient Descent
    # num_epochs - Number of training epochs
    # num_filters - Number of kernels for each convolution layer
    #               for e.g. 2 layers - [20, 50]. 
    #.              layer1 = 20, layer2 = 50
    # mini_batch_size - Mini-batch size to be used
    # activation - Activation function to use
    
    # Outputs:
    # Plot of the cost, prediction errors on validation set and
    # visualisation of weights of the first convolutional layer
    
    # Partitioning into mini- batches
    n_train_batches = train_set_x.get_value(borrow=True).shape[0]
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0]
    n_test_batches = test_set_x.get_value(borrow=True).shape[0]
    n_train_batches //= mini_batch_size
    n_valid_batches //= mini_batch_size
    n_test_batches //= mini_batch_size

    print('train: %d batches, test: %d batches,'
          ' validation: %d batches'
          % (n_train_batches, n_test_batches, n_valid_batches))
    
    mb_index = T.lscalar() # mini-batch index
    x = T.matrix('x') # rasterised images
    y = T.ivector('y') # image labels
    layer_weights = [];
    print('***** Constructing model ***** ')

    # Reshaping matrix of mini_batch_size set of images into a 
    # 4-D tensor 
    layer0_input = x.reshape((mini_batch_size, 1, 28, 28))

    ################# Insert Your Code Here ###################

    # Construct first convolution and pooling layer
    # Hint: Use the convLayer function. See demonstration.
    [layer0_output, layer0_params] = convLayer(
    rng,
    data_input=layer0_input,
    image_spec=(mini_batch_size, 1, 28, 28),
    filter_spec=(num_filters[0], 1, 5, 5),
    pool_size=(2, 2),
    activation=activation)

    #layer0_input = x.reshape((layer0_output, 9, 12, 12))


    # Construct second convolution and pooling layer
    # Hint: Use the convLayer function. See demonstration.
    [layer1_output, layer1_params] = convLayer(
    rng,
    data_input=layer0_output,
    image_spec=(mini_batch_size, num_filters[0], 12, 12),
    filter_spec=(num_filters[1], num_filters[0], 5, 5),
    pool_size=(2, 2),
    activation=activation)


    # Classify the values using the fully-connected
    # activation layer.
    # Hint: Remember to flatten the output from the 
    # convolutional layer. Use the fullyConnectedLayer function.
    # See demonstration.
    fc_layer_input = layer1_output.flatten(2)
    
    [p_y_given_x, y_pred, fc_layer_params] = fullyConnectedLayer(
    data_input=fc_layer_input,
    num_in=num_filters[1]*4*4,
    num_out=10)



    ##########################################################

    # Cost that is minimised during stochastic descent.
    cost = negative_log_lik(y=y, p_y_given_x=p_y_given_x)

    # Creating a function that computes the mistakes on the test set
    # mb_index is the mini_batch_index
    test_model = theano.function(
        [mb_index],
        errors(y, y_pred),
        givens={
            x: test_set_x[
                mb_index * mini_batch_size:
                (mb_index + 1) * mini_batch_size],
            y: test_set_y[
                mb_index * mini_batch_size:
                (mb_index + 1) * mini_batch_size]})

    # Creating a function that computes the mistakes on the validation
    # set
    valid_model = theano.function(
        [mb_index],
        errors(y, y_pred),
        givens={
            x: valid_set_x[
                mb_index * mini_batch_size:
                (mb_index + 1) * mini_batch_size],
            y: valid_set_y[
                mb_index * mini_batch_size:
                (mb_index + 1) * mini_batch_size]})
    
    ################# Insert Your Code Here ###################

    # Create list of parameters to fit during training.
    # Hint: Include the parameters from the two convolution layers
    # and activation layer
    
    params = layer0_params + layer1_params + fc_layer_params
    
    ##########################################################
    
    # Creating a list of gradients
    grads = T.grad(cost, params)

    # Creating a function that updates the model parameters by SGD.
    # The updates list is created by looping over all 
    # params[i], grads[i]) pairs.
    updates = [(param_i, param_i - learning_rate * grad_i)
               for param_i, grad_i in zip(params, grads)]

    train_model = theano.function(
        [mb_index],
        cost,
        updates=updates,
        givens={
            x: train_set_x[
                mb_index * mini_batch_size:
                (mb_index + 1) * mini_batch_size],
            y: train_set_y[
                mb_index * mini_batch_size:
                (mb_index + 1) * mini_batch_size]})

    epoch = 0
    cost_arr = numpy.array([])
    valid_score_arr = numpy.array([])
    valid_score_arr = numpy.append(valid_score_arr, 1)

    print('***** Training model *****')
    if (num_epochs < 1):
        print("Too few epochs!")
        return
    while (epoch < num_epochs):
        epoch = epoch + 1
        print("Training in epoch: %d / %d" % (epoch, num_epochs),
              end='\r')
        for minibatch_index in range(n_train_batches):
            # Computing number of iterations performed or total number
            # of mini-batches executed.
            iter = (epoch - 1) * n_train_batches + minibatch_index
            # cost of each minibatch
            cost_ij = train_model(minibatch_index)
            cost_arr = numpy.append(cost_arr, cost_ij)

        # Computing loss on each validation mini-batch after each epoch
        valid_losses = [valid_model(i) for i in range(n_valid_batches)]
        valid_score_arr = numpy.append(
                                       valid_score_arr,
                                        numpy.mean(valid_losses))
    print('***** Training Complete *****')
    # Computing mean error rate on test set
    test_losses = [test_model(i) for i in range(n_test_batches)]
    test_score = numpy.mean(test_losses)
    print('Prediction error: %f %%' % (test_score * 100.))
    # Generating the plots
    generate_plot(cost_arr, range(1, iter+2),
                  valid_score_arr,
                  range(0, epoch+1),
                  layer0_params[0].get_value())

# %% [markdown]
# ### Experiment

# %% [markdown]
# <p>Now we shall define some hyper-parameters and evaluate the model. We will compute the final Prediction Error on the test set. To complete this assignment, you must do the following things:</p>
# <ol>
# <li>Set your parameters in the cell below</li>
# <li>Run the experiment. Then, describe and discuss it in the 'Conclusions' cell below. You must do this for each experiment that you run.</li>
# <li>Especially in CSC notebooks, do not forget to restart the kernel after each experiment.</li>
# <li>Repeat from step 1 and perform at least 4 experiments.</li>
# <li>Run the experiment with the best result again to display the plots in the final submission.</li>
# <li>Download the completed assignment as PDF and submit as usual. The final PDF will contain the plots from only your best experiment as well as the discussion of all your experiments in the 'Conclusions' cell.</li>
# </ol>

# %%
################# Insert Your Code Here ###################

# Description and examples of parameters to train_test_conv_net()

# learning_rate - Sets the learning rate for Stochastic Gradient
#                 Descent. e.g.: 0.1
# num_epochs - Sets the number of training epochs. E.g.: 10
# num_filters - Sets the number of kernels for each 
#               convolution layer. for e.g. 2 layers: [4, 8]
#               implies layer1 = 4, layer2 = 8
# mini_batch_size - Sets the mini-batch size to be used in 
#                   the experiment. E.g: 50
# activation - Sets the activation function to be used.
#              E.g.: T.tanh, 
# train_size - Sets the number of training samples to be used.
#              E.g. 6000. 

# Note: The Kernel may crash on too large values of the 
# num_epochs, num_filters, mini_batch_size and train_size due to 
# memory limitations. This may happen especially on CSC notebooks
# as it is a shared resource.
# If that happens use smaller values!

learning_rate_list = [0.0001, 0.001, 0.01, 0.1]
num_epochs_list = [10, 50, 100]
num_filters_layer1 = [2, 4, 8, 16]
num_filters_layer2 = [4, 8, 16, 32]
mini_batch_size_list = [10, 50, 100, 150, 200]
activation_list = [T.tanh, T.nnet.relu, T.nnet.sigmoid, T.nnet.softplus]
train_size_list = [600, 3000, 6000, 9000, 15000, 24000, 30000]

print('#num_epochs: 10')
print('#num_filters: [4, 8]')
print('#mini_batch_size: 50')
print('#activation: T.nnet.relu')
print('#train_size: 6000')
print("######### Learning Rate Testing #########")
num_epochs      = 10
num_filters     = [4, 8]
mini_batch_size = 50
activation      = T.nnet.relu
train_size      = 6000
for _list in learning_rate_list:
    learning_rate   = _list
    datasets = load_data('mnist.pkl.gz', train_size)
    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]
    print('#Learning Rate: %f rate' %(_list))
    train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)


print('#learning_rate: 0.1')
print('#num_epochs: 10')
print('#num_filters: [4, 8]')
print('#mini_batch_size: 50')
print('#train_size: 6000')
print("######### Activation Function Testing #########")
learning_rate   = 0.1
num_epochs      = 10
num_filters     = [4, 8]
mini_batch_size = 50
train_size      = 6000
for _list in activation_list:
    activation   = _list
    datasets = load_data('mnist.pkl.gz', train_size)
    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]
    print('#Activation Function: %s' %(_list))
    train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)


print('#learning_rate: 0.1')
print('#num_epochs: 10')
print('#mini_batch_size: 50')
print('#activation: T.nnet.relu')
print('#train_size: 6000')
print("######### Number of kernel Testing #########")
learning_rate   = 0.1
num_epochs      = 10
mini_batch_size = 50
activation      = T.nnet.relu
train_size      = 6000
for _list_layer2 in num_filters_layer2:
    for _list_layer1 in num_filters_layer1:
        num_filters   = [_list_layer1, _list_layer2]
        datasets = load_data('mnist.pkl.gz', train_size)
        train_set_x, train_set_y = datasets[0]
        valid_set_x, valid_set_y = datasets[1]
        test_set_x, test_set_y = datasets[2]
        print('#Number of kernel: %s' %(num_filters))
        train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)


print('#learning_rate: 0.1')
print('#num_epochs: 10')
print('#mini_batch_size: 50')
print('#activation: T.nnet.relu')
print('#num_filters: [4, 8]')
print('#train_size: 6000')
print("######### Mini Batch Size Testing #########")
learning_rate   = 0.1
num_epochs      = 10
num_filters     = [4, 8]
activation      = T.nnet.relu
train_size      = 6000
for _list in mini_batch_size_list:
    mini_batch_size   = _list
    datasets = load_data('mnist.pkl.gz', train_size)
    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]
    print('#mini batch size: %d' %(_list))
    train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)

print('#learning_rate: 0.1')
print('#num_epochs: 10')
print('#mini_batch_size: 50')
print('#activation: T.nnet.relu')
print('#num_filters: [4, 8]')
print("######### Training Size Testing #########")
learning_rate   = 0.1
num_epochs      = 10
mini_batch_size = 50
num_filters     = [4, 8]
activation      = T.nnet.relu
for _list in train_size_list:
    train_size   = _list
    datasets = load_data('mnist.pkl.gz', train_size)
    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]
    print('#train size: %d' %(_list))
    train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)


print('#learning_rate: 0.1')
print('#mini_batch_size: 50')
print('#activation: T.nnet.relu')
print('#num_filters: [4, 8]')
print('#train_size: 6000')
print("######### Number of Epochs Testing #########")
learning_rate   = 0.1
mini_batch_size = 50
num_filters     = [4, 8]
activation      = T.nnet.relu
train_size      = 6000
for _list in num_epochs_list:
    num_epochs   = _list
    datasets = load_data('mnist.pkl.gz', train_size)
    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]
    print('#number of epochs: %d' %(_list))
    train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)

print("#########The configuration that offers the best accuracy #########")

learning_rate   = 0.1
num_epochs      = 100
num_filters     = [16, 16]
mini_batch_size = 100
activation      = T.nnet.relu
train_size      = 30000

###########################################################

# Loading dataset
# We use only a subset of the full dataset.
# Validation and test sets will be 1/3 of train 
# set size
datasets = load_data('mnist.pkl.gz', train_size)
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]
print('Training set: %d samples'
      %(train_set_x.get_value(borrow=True).shape[0])) 
print('Test set: %d samples'
      %(test_set_x.get_value(borrow=True).shape[0]))
print('Validation set: %d samples'
      %(valid_set_x.get_value(borrow=True).shape[0]))

# Beginning the training process
train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)
# Out:
# #num_epochs: 10
# #num_filters: [4, 8]
# #mini_batch_size: 50
# #activation: T.nnet.relu
# #train_size: 6000
# ######### Learning Rate Testing #########
# ***** Loading data *****
# #Learning Rate: 0.000100 rate
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 90.500000 %
# ***** Loading data *****
# #Learning Rate: 0.001000 rate
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 87.900000 %
# ***** Loading data *****
# #Learning Rate: 0.010000 rate
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 7.550000 %
# ***** Loading data *****
# #Learning Rate: 0.100000 rate
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.250000 %
# #learning_rate: 0.1
# #num_epochs: 10
# #num_filters: [4, 8]
# #mini_batch_size: 50
# #train_size: 6000
# ######### Activation Function Testing #########
# ***** Loading data *****
# #Activation Function: Elemwise{tanh,no_inplace}
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.400000 %
# ***** Loading data *****
# #Activation Function: <function relu at 0x1113fa840>
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.100000 %
# ***** Loading data *****
# #Activation Function: sigmoid
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 10.400000 %
# ***** Loading data *****
# #Activation Function: softplus
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 5.450000 %
# #learning_rate: 0.1
# #num_epochs: 10
# #mini_batch_size: 50
# #activation: T.nnet.relu
# #train_size: 6000
# ######### Number of kernel Testing #########
# ***** Loading data *****
# #Number of kernel: [2, 4]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 5.050000 %
# ***** Loading data *****
# #Number of kernel: [4, 4]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 5.700000 %
# ***** Loading data *****
# #Number of kernel: [8, 4]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.000000 %
# ***** Loading data *****
# #Number of kernel: [16, 4]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.600000 %
# ***** Loading data *****
# #Number of kernel: [2, 8]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.550000 %
# ***** Loading data *****
# #Number of kernel: [4, 8]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.300000 %
# ***** Loading data *****
# #Number of kernel: [8, 8]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.200000 %
# ***** Loading data *****
# #Number of kernel: [16, 8]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.900000 %
# ***** Loading data *****
# #Number of kernel: [2, 16]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.300000 %
# ***** Loading data *****
# #Number of kernel: [4, 16]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.200000 %
# ***** Loading data *****
# #Number of kernel: [8, 16]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.900000 %
# ***** Loading data *****
# #Number of kernel: [16, 16]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.000000 %
# ***** Loading data *****
# #Number of kernel: [2, 32]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.250000 %
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ***** Loading data *****
# #Number of kernel: [4, 32]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.100000 %
# ***** Loading data *****
# #Number of kernel: [8, 32]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.450000 %
# ***** Loading data *****
# #Number of kernel: [16, 32]
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.850000 %
# #learning_rate: 0.1
# #num_epochs: 10
# #mini_batch_size: 50
# #activation: T.nnet.relu
# #num_filters: [4, 8]
# #train_size: 6000
# ######### Mini Batch Size Testing #########
# ***** Loading data *****
# #mini batch size: 10
# train: 600 batches, test: 200 batches, validation: 200 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.500000 %
# ***** Loading data *****
# #mini batch size: 50
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.250000 %
# ***** Loading data *****
# #mini batch size: 100
# train: 60 batches, test: 20 batches, validation: 20 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 5.200000 %
# ***** Loading data *****
# #mini batch size: 150
# train: 40 batches, test: 13 batches, validation: 13 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.102564 %
# ***** Loading data *****
# #mini batch size: 200
# train: 30 batches, test: 10 batches, validation: 10 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 4.650000 %
# #learning_rate: 0.1
# #num_epochs: 10
# #mini_batch_size: 50
# #activation: T.nnet.relu
# #num_filters: [4, 8]
# ######### Training Size Testing #########
# ***** Loading data *****
# #train size: 600
# train: 12 batches, test: 4 batches, validation: 4 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 14.500000 %
# ***** Loading data *****
# #train size: 3000
# train: 60 batches, test: 20 batches, validation: 20 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 6.500000 %
# ***** Loading data *****
# #train size: 6000
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 5.050000 %
# ***** Loading data *****
# #train size: 9000
# train: 180 batches, test: 60 batches, validation: 60 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.466667 %
# ***** Loading data *****
# #train size: 15000
# train: 300 batches, test: 100 batches, validation: 100 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.860000 %
# ***** Loading data *****
# #train size: 24000
# train: 480 batches, test: 160 batches, validation: 160 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.662500 %
# ***** Loading data *****
# #train size: 30000
# train: 600 batches, test: 200 batches, validation: 200 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 2.160000 %
# #learning_rate: 0.1
# #mini_batch_size: 50
# #activation: T.nnet.relu
# #num_filters: [4, 8]
# #train_size: 6000
# ######### Number of Epochs Testing #########
# ***** Loading data *****
# #number of epochs: 10
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.600000 %
# ***** Loading data *****
# #number of epochs: 50
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.350000 %
# ***** Loading data *****
# #number of epochs: 100
# train: 120 batches, test: 40 batches, validation: 40 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 3.850000 %
# #########The configuration that offers the best accuracy #########
# ***** Loading data *****
# Training set: 30000 samples
# Test set: 10000 samples
# Validation set: 10000 samples
# train: 300 batches, test: 100 batches, validation: 100 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 1.550000 %

# %% [markdown]
# <p>Now go ahead and experiment with different hyper-parameters such as different number of filters, different number of convolution layers, activation functions etc;. Try to find out which configuration gives the best accuracy.</p>

# %%
print("#########The Final configuration that offers the best accuracy #########")

learning_rate   = 0.1
num_epochs      = 50
num_filters     = [8, 32]
mini_batch_size = 50
activation      = T.nnet.relu
train_size      = 30000

###########################################################

# Loading dataset
# We use only a subset of the full dataset.
# Validation and test sets will be 1/3 of train 
# set size
datasets = load_data('mnist.pkl.gz', train_size)
train_set_x, train_set_y = datasets[0]
valid_set_x, valid_set_y = datasets[1]
test_set_x, test_set_y = datasets[2]
print('Training set: %d samples'
      %(train_set_x.get_value(borrow=True).shape[0])) 
print('Test set: %d samples'
      %(test_set_x.get_value(borrow=True).shape[0]))
print('Validation set: %d samples'
      %(valid_set_x.get_value(borrow=True).shape[0]))

# Beginning the training process
train_test_conv_net(learning_rate, num_epochs, num_filters, mini_batch_size, activation)
# Out:
# #########The Final configuration that offers the best accuracy #########
# ***** Loading data *****
# Training set: 30000 samples
# Test set: 10000 samples
# Validation set: 10000 samples
# train: 600 batches, test: 200 batches, validation: 200 batches
# ***** Constructing model *****
# ***** Training model *****
# ***** Training Complete *****
# Prediction error: 1.250000 %

# %% [markdown]
# ### Conclusions

# %% [markdown]
# For my Experiment result:
# <ul>
# The best accuracy result is : Prediction error: 1.250000 %
# </ul>
# I run the following data in the loop to catch the best accuracy of two convolution layers.
# <ul>
# <li>learning_rate_list = [0.0001, 0.001, 0.01, 0.1]</li>
# <li>num_epochs_list = [10, 50, 100]</li>
# <li>num_filters_layer1 = [2, 4, 8, 16]</li>
# <li>num_filters_layer2 = [4, 8, 16, 32]</li>
# <li>mini_batch_size_list = [10, 50, 100, 150, 200]</li>
# <li>activation_list = [T.tanh, T.nnet.relu, T.nnet.sigmoid, T.nnet.softplus]</li>
# <li>train_size_list = [600, 3000, 6000, 9000, 15000, 24000, 30000]</li>
# </ul>
#
# The best result that I got from the rest configuration:
# <ul>
# <li>learning_rate   = 0.1</li>
# <li>num_epochs      = 50</li>
# <li>num_filters     = [8, 32]</li>
# <li>mini_batch_size = 50</li>
# <li>activation      = T.nnet.relu</li>
# <li>train_size      = 30000</li>
# </ul>
#
# The data analysis:
#
# <ul>
# learning rate:
# According to the reference [1] too high learning rate would decay the loss faster, but they get stuck at worse values of loss , so I decide to find the learning rate in the range of [0.0001, 0.1] , after the test result, when the learning rate of 0.1. the accuracy is the best.
# </ul>
#
# <ul>
# num epochs:
# Before the overfitting. more training iteration can increase the better accuracy rate. And the best result that I got is with 50 iteration.
# </ul>
#
# <ul>
# num_filters:
# After the different kernel number in different layer of convolution. before the overfitting of number_filters. [8,32] has the best accuracy rate that i got. So it means the high value can get the better result, but it still have chance to be overfitting.
# </ul>
#
# <ul>
# mini_batch_size:
# Before the overfitting. the number of 50 is the best result that I got.
# </ul>
#
# <ul>
# activation function:
# According to the result of T.tanh, T.nnet.relu, T.nnet.sigmoid, T.nnet.softplus. Relu has the best accuracy. refer to the link [2]
# </ul>
#
# <ul>
# train_size:
# When the CNN has more data to training, the accuracy will get better. so when the train size is 30000, the accuracy result is better than the other value.
# </ul>
#
# Reference:
# <ul>
# <li>[1] http://cs231n.github.io/neural-networks-3/</li>
# <li>[2] http://apprize.info/data/learning/5.html</li>
# </ul>
